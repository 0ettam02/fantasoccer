# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD
dataset1 = pd.read_csv("datasetGol.csv", sep=";")
dataset2 = pd.read_csv("Statistiche_Fantacalcio_Stagione_2024_25.csv", sep=";")

dataset1["Mv"] = dataset1["Mv"].str.replace(",", ".").astype(float)
dataset1["Fm"] = dataset1["Fm"].str.replace(",", ".").astype(float)

dataset2["Mv"] = dataset2["Mv"].str.replace(",", ".").astype(float)
dataset2["Fm"] = dataset2["Fm"].str.replace(",", ".").astype(float)

X = dataset1[["Ass", "Mv", "Fm", "Rc"]]
y = dataset1['Gf']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

ss = StandardScaler()
X_train = ss.fit_transform(X_train)
X_test = ss.transform(X_test)

model = Sequential()
model.add(Dense(12, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(24, activation='relu'))
model.add(Dense(36, activation='relu'))
model.add(Dense(42, activation='relu'))
model.add(Dense(1, activation='linear'))  

model.compile(optimizer=SGD(learning_rate=0.01), loss='mean_squared_error', metrics=['accuracy'])

model.fit(X_train, y_train, epochs=100) 

def predict_goal(player_data):
    if player_data.empty:
        print("No player data found.")
        return None  

    player_data_normalized = ss.transform(player_data[["Ass", "Mv", "Fm", "Rc"]])
    predicted_goal = model.predict(player_data_normalized).mean()
    return predicted_goal

giocatore = str(input("inserisci il nome del giocatore "))

if giocatore in dataset2['Nome'].values:
    giocatore_data = dataset1[dataset1['Nome'] == giocatore]
    predicted_goal = predict_goal(giocatore_data.copy())  
    if predicted_goal is not None:
        print(f"Predicted average goals for {giocatore}: {predicted_goal:.2f}") 
else:
    print(f"Player '{giocatore}' not found in Serie A 2024-25 data.")
# Out:
# Epoch 1/100
# 116/116 [==============================] - 1s 2ms/step - loss: 5.9078 - accuracy: 0.4106
# Epoch 2/100
# 116/116 [==============================] - 0s 2ms/step - loss: 6.3330 - accuracy: 0.4244
# Epoch 3/100
# 116/116 [==============================] - 0s 2ms/step - loss: 4.0951 - accuracy: 0.5726
# Epoch 4/100
# 116/116 [==============================] - 0s 2ms/step - loss: 3.1728 - accuracy: 0.5905
# Epoch 5/100
# 116/116 [==============================] - 0s 2ms/step - loss: 2.8747 - accuracy: 0.5940
# Epoch 6/100
# 116/116 [==============================] - 0s 2ms/step - loss: 2.3939 - accuracy: 0.5997
# Epoch 7/100
# 116/116 [==============================] - 0s 2ms/step - loss: 2.6115 - accuracy: 0.5924
# Epoch 8/100
# 116/116 [==============================] - 0s 2ms/step - loss: 2.7764 - accuracy: 0.5959
# Epoch 9/100
# 116/116 [==============================] - 0s 2ms/step - loss: 2.2778 - accuracy: 0.5978
# Epoch 10/100
# 116/116 [==============================] - 0s 2ms/step - loss: 2.4188 - accuracy: 0.5970
# Epoch 11/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.7750 - accuracy: 0.6021
# Epoch 12/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.8446 - accuracy: 0.6029
# Epoch 13/100
# 116/116 [==============================] - 0s 2ms/step - loss: 2.1636 - accuracy: 0.5951
# Epoch 14/100
# 116/116 [==============================] - 0s 2ms/step - loss: 2.2626 - accuracy: 0.6029
# Epoch 15/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.7448 - accuracy: 0.6094
# Epoch 16/100
# 116/116 [==============================] - 0s 2ms/step - loss: 3.5805 - accuracy: 0.5585
# Epoch 17/100
# 116/116 [==============================] - 0s 2ms/step - loss: 3.9022 - accuracy: 0.5647
# Epoch 18/100
# 116/116 [==============================] - 0s 2ms/step - loss: 2.5913 - accuracy: 0.5818
# Epoch 19/100
# 116/116 [==============================] - 0s 2ms/step - loss: 2.0182 - accuracy: 0.5842
# Epoch 20/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.9462 - accuracy: 0.5986
# Epoch 21/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.9458 - accuracy: 0.5943
# Epoch 22/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.6260 - accuracy: 0.5948
# Epoch 23/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.7313 - accuracy: 0.6081
# Epoch 24/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.6080 - accuracy: 0.6059
# Epoch 25/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.7301 - accuracy: 0.6062
# Epoch 26/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.8038 - accuracy: 0.6092
# Epoch 27/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.6796 - accuracy: 0.6108
# Epoch 28/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.3523 - accuracy: 0.6151
# Epoch 29/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.4539 - accuracy: 0.6197
# Epoch 30/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.4093 - accuracy: 0.6154
# Epoch 31/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.4457 - accuracy: 0.6159
# Epoch 32/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.3004 - accuracy: 0.6119
# Epoch 33/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.3641 - accuracy: 0.6186
# Epoch 34/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.4225 - accuracy: 0.6208
# Epoch 35/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.8416 - accuracy: 0.6157
# Epoch 36/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.3633 - accuracy: 0.6246
# Epoch 37/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.3228 - accuracy: 0.6230
# Epoch 38/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.3313 - accuracy: 0.6211
# Epoch 39/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.3009 - accuracy: 0.6232
# Epoch 40/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.4781 - accuracy: 0.6227
# Epoch 41/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.2862 - accuracy: 0.6219
# Epoch 42/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.4880 - accuracy: 0.6270
# Epoch 43/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.3820 - accuracy: 0.6276
# Epoch 44/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.2565 - accuracy: 0.6292
# Epoch 45/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.2970 - accuracy: 0.6222
# Epoch 46/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.4942 - accuracy: 0.6287
# Epoch 47/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.4707 - accuracy: 0.6238
# Epoch 48/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.3158 - accuracy: 0.6268
# Epoch 49/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.4555 - accuracy: 0.6292
# Epoch 50/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.3230 - accuracy: 0.6276
# Epoch 51/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.2948 - accuracy: 0.6292
# Epoch 52/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.2550 - accuracy: 0.6289
# Epoch 53/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.1980 - accuracy: 0.6300
# Epoch 54/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.3191 - accuracy: 0.6303
# Epoch 55/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.3629 - accuracy: 0.6333
# Epoch 56/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.3637 - accuracy: 0.6243
# Epoch 57/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.2542 - accuracy: 0.6354
# Epoch 58/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.2715 - accuracy: 0.6303
# Epoch 59/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.3030 - accuracy: 0.6324
# Epoch 60/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.0934 - accuracy: 0.6354
# Epoch 61/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.1994 - accuracy: 0.6338
# Epoch 62/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.1913 - accuracy: 0.6362
# Epoch 63/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.4313 - accuracy: 0.6292
# Epoch 64/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.3287 - accuracy: 0.6335
# Epoch 65/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.2616 - accuracy: 0.6278
# Epoch 66/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.2496 - accuracy: 0.6303
# Epoch 67/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.1604 - accuracy: 0.6346
# Epoch 68/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.1750 - accuracy: 0.6297
# Epoch 69/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.1153 - accuracy: 0.6316
# Epoch 70/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.3232 - accuracy: 0.6365
# Epoch 71/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.1490 - accuracy: 0.6297
# Epoch 72/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.2404 - accuracy: 0.6341
# Epoch 73/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.0924 - accuracy: 0.6360
# Epoch 74/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.2348 - accuracy: 0.6330
# Epoch 75/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.1701 - accuracy: 0.6387
# Epoch 76/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.2521 - accuracy: 0.6371
# Epoch 77/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.2483 - accuracy: 0.6324
# Epoch 78/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.1779 - accuracy: 0.6368
# Epoch 79/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.2582 - accuracy: 0.6341
# Epoch 80/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.1392 - accuracy: 0.6333
# Epoch 81/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.1667 - accuracy: 0.6403
# Epoch 82/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.1420 - accuracy: 0.6422
# Epoch 83/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.2226 - accuracy: 0.6343
# Epoch 84/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.1756 - accuracy: 0.6365
# Epoch 85/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.1950 - accuracy: 0.6381
# Epoch 86/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.3235 - accuracy: 0.6376
# Epoch 87/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.2007 - accuracy: 0.6408
# Epoch 88/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.2404 - accuracy: 0.6430
# Epoch 89/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.1680 - accuracy: 0.6362
# Epoch 90/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.1853 - accuracy: 0.6398
# Epoch 91/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.2462 - accuracy: 0.6365
# Epoch 92/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.1864 - accuracy: 0.6395
# Epoch 93/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.1388 - accuracy: 0.6365
# Epoch 94/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.2132 - accuracy: 0.6362
# Epoch 95/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.1729 - accuracy: 0.6430
# Epoch 96/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.3888 - accuracy: 0.6425
# Epoch 97/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.2119 - accuracy: 0.6398
# Epoch 98/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.0841 - accuracy: 0.6408
# Epoch 99/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.1169 - accuracy: 0.6438
# Epoch 100/100
# 116/116 [==============================] - 0s 2ms/step - loss: 1.1624 - accuracy: 0.6406
# Player 'Vlaohvic' not found in Serie A 2024-25 data.
